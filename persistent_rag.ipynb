# %%
import sys
from pathlib import Path

project_root = Path("/Users/veneraheddergott/LLM_zoomcamp/llm-zoomcamp_2026_vh")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from rag_helper import RAGBase
from ingest import load_faq_data

# %%
from sqlitesearch import TextSearchIndex

sqlite_index = TextSearchIndex(
    text_fields=["question", "section", "answer"],
    keyword_fields=["course"],
    db_path="faq.db"
)

# %%
len(sqlite_index.search(''))

# %%
docs_llm = [doc for doc in documents if doc["course"] == "llm-zoomcamp"]
print(f"LLM Zoomcamp: {len(docs_llm)} documents")

# %%
sqlite_index.search('how do I join the course')

# %%
from dotenv import dotenv_values, load_dotenv
from openai import OpenAI
from pathlib import Path
import os

project_root = Path("/Users/veneraheddergott/LLM_zoomcamp/llm-zoomcamp_2026_vh")
env_path = project_root / ".env"
load_dotenv(env_path, override=True)

api_key = os.environ.get("GROQ_API_KEY") or dotenv_values(env_path).get("GROQ_API_KEY")
if not api_key:
    raise ValueError("GROQ_API_KEY fehlt. Trage ihn in die .env-Datei ein.")

openai_client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=api_key
)

# %%
from rag_helper import RAGBase
assistant = RAGBase(sqlite_index, openai_client, model="llama-3.3-70b-versatile")

# %%
assistant.rag("I just discovered the course. Can I still join ?")

# %%
#rag is the most common application!
