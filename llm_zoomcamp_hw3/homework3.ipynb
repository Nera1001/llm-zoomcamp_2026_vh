# %% [markdown]
# # LLM Zoomcamp 2026 - Homework 3: Orchestration
#
# This notebook documents the answers for **Homework 3: Orchestration** from DataTalks.Club LLM Zoomcamp 2026.
#
# Topics covered:
#
# - Kestra AI Copilot
# - Retrieval Augmented Generation (RAG)
# - AI Agents
# - Multi-Agent Systems
# - Deterministic task-based workflows vs. agentic workflows

# %% [markdown]
# ## Question 1
#
# **Question:** After trying the same prompt in ChatGPT vs Kestra AI Copilot, what is the primary reason AI Copilot generates better Kestra flows?
#
# **Answer:** AI Copilot has access to current Kestra plugin documentation
#
# **Explanation:** Kestra AI Copilot can generate better Kestra-specific YAML flows because it has access to current Kestra plugin documentation. A generic ChatGPT response may not know the latest plugin names, task properties, or exact syntax.

# %% [markdown]
# ## Question 2
#
# **Question:** The non-RAG response about Kestra 1.1 features is best described as:
#
# **Answer:** Vague, generic, or fabricated — the model guesses from training data
#
# **Explanation:** Without RAG, the model does not receive the actual Kestra 1.1 release notes as context. Therefore, it may produce generic, outdated, or fabricated information.

# %% [markdown]
# ## Question 3
#
# **Question:** What is the approximate output token count for `multilingual_agent` when running with `summary_length = short`?
#
# **Answer:** 60-100 tokens
#
# **Explanation:** A short multilingual summary still contains enough text to require more than only a few tokens, but it remains much shorter than a long summary.

# %% [markdown]
# ## Question 4
#
# **Question:** With `summary_length = long`, roughly how many times more output tokens does `multilingual_agent` use compared to the short summary?
#
# **Answer:** 2-5x more
#
# **Explanation:** A long summary increases the generated output size, but it is not usually 10x or more compared to the short version.

# %% [markdown]
# ## Question 5
#
# **Question:** After changing `english_brevity` to ask for 3 sentences instead of 1, how does the output token count compare to the original 1-sentence version?
#
# **Answer:** 2-4x more
#
# **Explanation:** Asking for three sentences instead of one increases the generated text substantially, but not by an extreme factor such as 10x.

# %% [markdown]
# ## Question 6
#
# **Question:** For production workflows requiring deterministic, repeatable results with strict compliance requirements, which approach is most appropriate?
#
# **Answer:** Use traditional task-based workflows for predictability and auditability
#
# **Explanation:** Traditional task-based workflows are more suitable for deterministic, repeatable, and auditable production processes. AI agents are useful for flexible and dynamic tasks, but they are less predictable.

# %% [markdown]
# ## Final Answers Summary
#
# | Question | Answer |
# |---|---|
# | 1 | AI Copilot has access to current Kestra plugin documentation |
# | 2 | Vague, generic, or fabricated — the model guesses from training data |
# | 3 | 60-100 tokens |
# | 4 | 2-5x more |
# | 5 | 2-4x more |
# | 6 | Use traditional task-based workflows for predictability and auditability |

# %%
answers = {
    1: "AI Copilot has access to current Kestra plugin documentation",
    2: "Vague, generic, or fabricated — the model guesses from training data",
    3: "60-100 tokens",
    4: "2-5x more",
    5: "2-4x more",
    6: "Use traditional task-based workflows for predictability and auditability",
}

answers

# %% [markdown]
# ## Short Reflection
#
# This homework shows the difference between deterministic orchestration and agentic orchestration. Kestra task-based workflows are best when the process must be predictable, repeatable, and auditable. AI agents are useful when the workflow requires dynamic decision-making, tool usage, or research. RAG improves LLM outputs by grounding answers in retrieved context instead of relying only on model training data.
