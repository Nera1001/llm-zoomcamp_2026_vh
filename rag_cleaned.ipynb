# %%
import sys
from pathlib import Path

project_root = Path("/Users/veneraheddergott/LLM_zoomcamp/llm-zoomcamp_2026_vh")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from rag_helper import RAGBase
from ingest import load_faq_data, build_index

# %%
from dotenv import load_dotenv
from openai import OpenAI
import os

load_dotenv(override=True)

if os.getenv("GROQ_API_KEY") is None:
    raise ValueError("GROQ_API_KEY wurde nicht gefunden. Bitte .env prüfen.")

llm_client = OpenAI(
    api_key=os.getenv("GROQ_API_KEY"),
    base_url="https://api.groq.com/openai/v1",
)

# %%
assistant = RAGBase(index=index, llm_client=llm_client, model="llama-3.3-70b-versatile")

# %%
len(documents)
# Out:
# 1350

# %%
assistant = RAGBase(index=index, llm_client=llm_client, model="llama-3.3-70b-versatile")
# Out:
# Yes, you can still join the course. However, if you want to receive a certificate, you need to submit your project while submissions are still being accepted. You can start learning and submitting homework without registering, and you can follow the course workflow as described in the provided context.
