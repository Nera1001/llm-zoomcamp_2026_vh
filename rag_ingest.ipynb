# %%
import sys
from pathlib import Path

project_root = Path("/Users/veneraheddergott/LLM_zoomcamp/llm-zoomcamp_2026_vh")
if str(project_root) not in sys.path:
    sys.path.insert(0, str(project_root))

from ingest import load_faq_data, build_index

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
from dotenv import dotenv_values, load_dotenv
from openai import OpenAI
from pathlib import Path
import os

project_root = Path("/Users/veneraheddergott/LLM_zoomcamp/llm-zoomcamp_2026_vh")
env_path = project_root / ".env"
load_dotenv(env_path, override=True)

api_key = os.environ.get("GROQ_API_KEY") or dotenv_values(env_path).get("GROQ_API_KEY")
if not api_key:
    raise ValueError("GROQ_API_KEY fehlt. Trage ihn in die .env-Datei ein oder setze ihn vor dem Kernel-Start als Umgebungsvariable.")

client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=api_key
)

# %%
from rag_helper import RAGBase

assistant = RAGBase(index=index, llm_client=client, model="llama-3.3-70b-versatile")

# %%
answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# You can join the course now. However, if you want to receive a certificate, you need to submit your project while the course is still accepting submissions. You can start learning and submitting homework without registration, and follow the weekly workflow as described in the course materials.

# %%
assistant.rag("How do I get a certificate?")
assistant.rag("Can I still join the course after it started?")
# Out:
# 'Yes, you can still join the course after it started. However, if you want to receive a certificate, you need to submit your project while submissions are still being accepted. Additionally, you should follow the course with a "live" cohort, as certificates are not awarded for self-paced mode.'

# %%
assistant.rag(" Tell me about homework?")
# Out:
# "Homework for the course can be found in two locations: the course GitHub repository and the course management platform. The GitHub repository contains detailed instructions and important context for the homework, while the course platform is useful for submission and deadlines.\n\nFor the 2026 Module 1 homework, specific materials and instructions can be found at:\n- [Module 1 cohort materials](https://github.com/DataTalksClub/llm-zoomcamp/tree/main/cohorts/2026/01-agentic-rag)\n- [Module 1 homework instructions](https://github.com/DataTalksClub/llm-zoomcamp/blob/main/cohorts/2026/01-agentic-rag/homework.md)\n\nHomework answers do not always need to match the options exactly. If your numeric answer is close to one of the options, you should choose the closest option. Small differences can come from slightly different filtering, different dataset versions, floating-point or rounding differences, or different model/provider behavior.\n\nIf homework questions feel unclear, you should first read the GitHub homework instructions. The homework follows the lesson workflow but usually uses a different dataset or asks you to apply the same idea in a slightly different way. If it is still unclear, you can ask in Slack and include the code or command output as text, following the [asking questions guidelines](https://datatalks.club/docs/courses/zoomcamp-logistics/asking-questions/).\n\nWhen working on homework, especially with different providers, you should get the token count from the model response object. For example, OpenAI-compatible clients usually return usage information on the response. If your provider does not expose token usage, you can use that provider's native tokenizer as an approximation. For multiple-choice homework questions, choose the closest option.\n\nIn Module 1 homework, when pointing RAG at the chunk index, it means you should build and search the index using the chunked documents, not the original full documents. This reduces the amount of context sent to the model. \n\nFor general guidance on homework logistics, you can refer to [homework logistics](https://datatalks.club/docs/courses/zoomcamp-logistics/homework/)."
