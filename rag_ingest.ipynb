# %%
from ingest import load_faq_data, build_index

# %%
documents = load_faq_data()
index = build_index(documents)

# %%
from dotenv import load_dotenv
load_dotenv()

from openai import OpenAI
import os

client = OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.environ.get("GROQ_API_KEY")
)

# %%
from rag_helper import RAGBase

assistant = RAGBase(index=index, llm_client=client, model="llama-3.3-70b-versatile")

# %%
answer = assistant.rag("I just discovered the course. Can I join now?")
print(answer)
# Out:
# Yes, you can still join the course. However, if you want to receive a certificate, you need to submit your project while the course is still accepting submissions. You can start the course whenever you want and follow the weekly workflow as described in the provided context.

# %%
assistant.rag("How do I get a certificate?")
assistant.rag("Can I still join the course after it started?")
# Out:
# 'Yes, you can still join the course after it has started. However, if you want to receive a certificate, you need to submit your project while submissions are still being accepted. Additionally, you should follow the course with a "live" cohort, as certificates are not awarded for self-paced mode. You can start by following the weekly workflow outlined in the provided context.'

# %%
assistant.rag(" Tell me about homework?")
# Out:
# 'Homework in the context provided refers to assignments given in a course, specifically Module 1. Here are key points about homework:\n\n1. **Location of Homework Questions**: Homework links are available in the course GitHub repository and in the course management platform.\n2. **Submission and Deadlines**: The course platform is useful for submission and deadlines.\n3. **Importance of GitHub Instructions**: GitHub homework instructions often contain important extra context, including specific instructions for the cohort and module.\n4. **Exactness of Answers**: Answers do not always need to match the options exactly. If a numeric answer is close to one of the options, choose the closest option. Small differences can come from filtering, dataset versions, floating-point or rounding differences, or different model/provider behavior.\n5. **Clarifying Unclear Questions**: If homework questions feel unclear, first read the GitHub homework instructions. If still unclear, ask in Slack, including code or command output as text.\n6. **Token Counts for Different Providers**: For getting token counts when using a different provider, get the token count from the model response object. If the provider does not expose token usage, use its native tokenizer as an approximation.\n7. **Pointing RAG at the Chunk Index**: This means building and searching the index using chunked documents, not the original full documents. Fit the search index on the chunks, not the full documents.\n\nFor more information, refer to the provided GitHub links for the specific module and cohort, and the general homework guidance and asking questions guidelines on the course website.'
