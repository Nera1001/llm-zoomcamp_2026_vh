# %%
import ingest
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from ingest import load_faq_data
#
# ImportError: cannot import name 'load_faq_data' from 'ingest' (/workspaces/llm-zoomcamp_2026_vh/ingest.py)
